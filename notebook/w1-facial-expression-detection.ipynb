# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
from keras.models import Model, Sequential
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from keras.optimizers import Adam, SGD, RMSprop
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle                      
import cv2                                 
import tensorflow as tf
# Out:
# 2024-06-13 03:48:45.639589: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-13 03:48:45.639737: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-13 03:48:45.793730: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
class_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)

IMAGE_SIZE = (50, 50)

def load_data():
    datasets = ['/kaggle/input/face-expression-recognition-dataset/images/train/']
    output = []
    
    # Iterate through training and test sets
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            count = 0
            # Iterate through each image in our folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
                # Open and resize the img
#                 image = cv2.imread(img_path)
                image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#                 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE) 
                
                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)
                
                # Taking 2k images from of each type because of MemoryError
                count = count + 1
                if count == 2000:
                    break
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %%
(images, labels) = load_data()[0]
# Out:
# Loading /kaggle/input/face-expression-recognition-dataset/images/train/
#  62%|██████▏   | 1999/3205 [00:11<00:06, 177.97it/s]
#  49%|████▊     | 1999/4103 [00:11<00:11, 175.53it/s]
#  50%|█████     | 1999/3993 [00:11<00:11, 176.18it/s]
#  40%|████      | 1999/4982 [00:10<00:15, 187.60it/s]
#  40%|████      | 1999/4938 [00:10<00:16, 182.98it/s]
# 100%|██████████| 436/436 [00:02<00:00, 202.23it/s]
#  28%|██▊       | 1999/7164 [00:11<00:28, 178.28it/s]

# %%
permutation  = np.random.permutation(len(images))

shuffled_images = images[permutation]
shuffled_labels = labels[permutation]

# %%
from sklearn.model_selection import train_test_split

train_images, test_images, train_labels, test_labels = train_test_split(shuffled_images, shuffled_labels, test_size=0.1, shuffle=True)

train_images.shape, train_labels.shape, test_images.shape, test_labels.shape
# Out:
# ((11192, 50, 50), (11192,), (1244, 50, 50), (1244,))

# %%
train_images = train_images / 255.0 
test_images = test_images / 255.0

# %%
def display_random_image(class_names, images, labels):   
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()
    
display_random_image(class_names, train_images, train_labels)

# %%
model2 = tf.keras.Sequential([
    tf.keras.layers.Conv2D(16, (3, 3), activation = 'relu', input_shape = (50, 50, 1)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.2),
    
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.2),
    
    tf.keras.layers.Conv2D(64, (3, 3), activation = 'relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.2),
    
    tf.keras.layers.Conv2D(128, (3, 3), activation = 'relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    
    tf.keras.layers.Dense(7, activation='softmax')
])

model2.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])
model2.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 22, 22, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 22, 22, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 11, 11, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 11, 11, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 9, 9, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 9, 9, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 2, 2, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 2, 2, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 1, 1, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 1, 1, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 115,527 (451.28 KB)
#  Trainable params: 115,047 (449.40 KB)
#  Non-trainable params: 480 (1.88 KB)

# %%
history = model2.fit(train_images, train_labels, epochs=30, validation_split = 0.1)
# Out:
# Epoch 1/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 20s 52ms/step - accuracy: 0.1991 - loss: 2.1414 - val_accuracy: 0.1527 - val_loss: 2.3312
# Epoch 2/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 51ms/step - accuracy: 0.2670 - loss: 1.8062 - val_accuracy: 0.2991 - val_loss: 1.8184
# Epoch 3/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 50ms/step - accuracy: 0.3130 - loss: 1.7212 - val_accuracy: 0.2991 - val_loss: 1.8543
# Epoch 4/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 51ms/step - accuracy: 0.3563 - loss: 1.6532 - val_accuracy: 0.3705 - val_loss: 1.5888
# Epoch 5/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 49ms/step - accuracy: 0.3788 - loss: 1.6044 - val_accuracy: 0.3562 - val_loss: 1.6720
# Epoch 6/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 52ms/step - accuracy: 0.3923 - loss: 1.5653 - val_accuracy: 0.3866 - val_loss: 1.5635
# Epoch 7/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 50ms/step - accuracy: 0.4230 - loss: 1.5205 - val_accuracy: 0.4250 - val_loss: 1.5119
# Epoch 8/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 21s 52ms/step - accuracy: 0.4245 - loss: 1.4878 - val_accuracy: 0.3839 - val_loss: 1.5699
# Epoch 9/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 52ms/step - accuracy: 0.4484 - loss: 1.4305 - val_accuracy: 0.3536 - val_loss: 1.6999
# Epoch 10/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 52ms/step - accuracy: 0.4575 - loss: 1.4101 - val_accuracy: 0.4634 - val_loss: 1.3963
# Epoch 11/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 50ms/step - accuracy: 0.4649 - loss: 1.3799 - val_accuracy: 0.3982 - val_loss: 1.5560
# Epoch 12/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 17s 53ms/step - accuracy: 0.4881 - loss: 1.3408 - val_accuracy: 0.4455 - val_loss: 1.4429
# Epoch 13/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 20s 52ms/step - accuracy: 0.4990 - loss: 1.3079 - val_accuracy: 0.4812 - val_loss: 1.3827
# Epoch 14/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 17s 53ms/step - accuracy: 0.5083 - loss: 1.2885 - val_accuracy: 0.4688 - val_loss: 1.3965
# Epoch 15/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 51ms/step - accuracy: 0.5212 - loss: 1.2598 - val_accuracy: 0.4652 - val_loss: 1.3853
# Epoch 16/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 21s 52ms/step - accuracy: 0.5201 - loss: 1.2551 - val_accuracy: 0.4304 - val_loss: 1.4811
# Epoch 17/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 52ms/step - accuracy: 0.5284 - loss: 1.2372 - val_accuracy: 0.4589 - val_loss: 1.3696
# Epoch 18/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 52ms/step - accuracy: 0.5332 - loss: 1.2227 - val_accuracy: 0.4723 - val_loss: 1.4482
# Epoch 19/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 51ms/step - accuracy: 0.5586 - loss: 1.1722 - val_accuracy: 0.4991 - val_loss: 1.3245
# Epoch 20/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.5626 - loss: 1.1411 - val_accuracy: 0.4955 - val_loss: 1.3632
# Epoch 21/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 51ms/step - accuracy: 0.5617 - loss: 1.1334 - val_accuracy: 0.4607 - val_loss: 1.4326
# Epoch 22/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 51ms/step - accuracy: 0.5599 - loss: 1.1561 - val_accuracy: 0.4839 - val_loss: 1.4152
# Epoch 23/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 51ms/step - accuracy: 0.5863 - loss: 1.0908 - val_accuracy: 0.4759 - val_loss: 1.3990
# Epoch 24/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 52ms/step - accuracy: 0.5779 - loss: 1.1012 - val_accuracy: 0.4643 - val_loss: 1.4199
# Epoch 25/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.5856 - loss: 1.1088 - val_accuracy: 0.4795 - val_loss: 1.3807
# Epoch 26/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 51ms/step - accuracy: 0.6002 - loss: 1.0692 - val_accuracy: 0.4929 - val_loss: 1.3462
# Epoch 27/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 17s 53ms/step - accuracy: 0.6112 - loss: 1.0338 - val_accuracy: 0.5152 - val_loss: 1.3289
# Epoch 28/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 52ms/step - accuracy: 0.6095 - loss: 1.0425 - val_accuracy: 0.4991 - val_loss: 1.3680
# Epoch 29/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 17s 53ms/step - accuracy: 0.6017 - loss: 1.0442 - val_accuracy: 0.4902 - val_loss: 1.3951
# Epoch 30/30
# 315/315 ━━━━━━━━━━━━━━━━━━━━ 16s 50ms/step - accuracy: 0.6149 - loss: 1.0290 - val_accuracy: 0.5089 - val_loss: 1.3575

# %%
plt.plot(history.history['accuracy'], label = "acc")
plt.plot(history.history['val_accuracy'], label = "val_acc")
plt.title("train_acc vs val_acc")
plt.ylabel("accuracy")
plt.xlabel("epochs")
plt.legend()

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:skyblue;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h2 style='padding: 20px;
#               color:black;
#               text-align:center;'>
#         IF YOU LIKED THE NOTEBOOK PLEASE DO UPVOTE!
#     </h2>
#     </div>

# %%
predictions = model2.predict(test_images)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability

# Display predicted labels
for i in range(5):
    display_random_image(class_names, test_images, pred_labels)
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step

# %% [markdown]
# Gradient Descent
# 	Uses a fixed learning rate
# 	Generally slow and used for small datasets
# 	No bias correction
#
# RMSProp
# 	LR depends on avg of the squared gradients
# 	performs better than GD
# 	Used in Neural networks
# 	No bias correction
#
# Adam
# 	LR depends on avg of gradients (1st moment) and the variance of the gradients (2nd moment)
# 	Better than GD / RMSProp
# 	Used in Neural networks
# 	Bias correction in both first and second moments.
